# %% [markdown]
#    if game["name"] == game_name:
#             game.update(Game.model_dump())
#             return Game
#     return{"message":"game not found"}

# %% [markdown]
# @app.get("/games/")
# async def games() -> list[just_game]:
#     return [
#         just_game(game="GTA V",price=23213),
#         just_game(game="GTA IV",price=12312,discount=True),
#         just_game,
#     ]

# %% [markdown]
# from fastapi import FastAPI, Query
# from typing import Annotated
# from pydantic import BaseModel
#
# app = FastAPI()
# bikes = []
#
# class Bike(BaseModel):
#     name:  str        # ✅ colon
#     cc:    int
#     price: float
#
# @app.post("/query")
# async def query_typ(q: Annotated[str | None, Query()] = "thapa", bike: Bike = None):
#     bikes.append(bike.model_dump())
#     return {"message": "bikes added", "q": q, "bikes": bikes}
#
# @app.get("/send")
# async def get_bike():
#     return bikes
# ```
#
# ---
#
# ### Quick rule to remember:
# ```
# Enum        →  use =   (assigning values)
# BaseModel   →  use :   (type annotations)
# default     →  always outside Annotated, after )

# %% [markdown]
# # ❌ Wrong - this is like Enum syntax
# class Bike(BaseModel):
#     name = str    # assigning TYPE as value
#     cc = int
#     price = float
#
# # ✅ Correct - use : for BaseModel
# class Bike(BaseModel):
#     name: str     # type annotation
#     cc: int
#     price: float

# %% [markdown]
# # ❌ Wrong - this is like Enum syntax
# class Bike(BaseModel):
#     name = str    # assigning TYPE as value
#     cc = int
#     price = float
#
# # ✅ Correct - use : for BaseModel
# class Bike(BaseModel):
#     name: str     # type annotation
#     cc: int
#     price: float

# %% [markdown]
#     bought :Literal["yes","No"] = "No"
